# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import squarify

# %%
#Loading Dateset
exp_df = pd.read_csv("expenditures.txt",  sep='\t')

exp_df
# Out:
#      year             category  expenditure  sex
# 0    2008                 Food         6443    1
# 1    2008  Alcoholic Beverages          444    1
# 2    2008              Housing        17109    1
# 3    2008              Apparel         1801    1
# 4    2008       Transportation         8604    1
# ..    ...                  ...          ...  ...
# 345  1984            Education          303    1
# 346  1984     Tobacco Products          228    1
# 347  1984        Miscellaneous          451    1
# 348  1984   Cash Contributions          706    1
# 349  1984   Personal Insurance         1897    1
#
# [350 rows x 4 columns]

# %%
# Plotting treemap
exp_df_2000 = exp_df.loc[exp_df.year ==2000]
squarify.plot(sizes=exp_df_2000['expenditure'], label=exp_df_2000['category'], alpha=.8)
plt.axis('off')
plt.title('Expenditures by Category for the Year 2000')
plt.rcParams["figure.figsize"] = (12,10)
plt.show()

# %%
#Filtering dataset by Apparel Category
exp_app_df = exp_df.loc[exp_df.category == 'Apparel']
exp_app_df
# Out:
#      year category  expenditure  sex
# 3    2008  Apparel         1801    1
# 17   2007  Apparel         1881    1
# 31   2006  Apparel         1874    1
# 45   2005  Apparel         1886    1
# 59   2004  Apparel         1816    1
# 73   2003  Apparel         1640    1
# 87   2002  Apparel         1749    1
# 101  2001  Apparel         1743    1
# 115  2000  Apparel         1856    1
# 129  1999  Apparel         1743    1
# 143  1998  Apparel         1674    1
# 157  1997  Apparel         1729    1
# 171  1996  Apparel         1752    1
# 185  1995  Apparel         1704    1
# 199  1994  Apparel         1644    1
# 213  1993  Apparel         1676    1
# 227  1992  Apparel         1710    1
# 241  1991  Apparel         1735    1
# 255  1990  Apparel         1618    1
# 269  1989  Apparel         1582    1
# 283  1988  Apparel         1489    1
# 297  1987  Apparel         1446    1
# 311  1986  Apparel         1346    1
# 325  1985  Apparel         1420    1
# ...

# %%
# Plotting Area map
plt.fill_between(exp_app_df['year'], exp_app_df['expenditure'], alpha=0.8)
plt.plot(exp_app_df['year'], exp_app_df['expenditure'], alpha=0.6)
plt.title('Expenditures by Year for Apparel Category', fontsize=10)
plt.xlabel('Year')
plt.ylabel('Expenditure')
plt.show()

# %%
# Plotting Stacked Area map
exp_df.groupby(['year','category'])['expenditure'].sum().unstack().plot(kind='area', stacked=True)
plt.title('Expenditure by Year for all Categories') 
plt.xlabel('Year')
plt.ylabel('Total Expenditure')
plt.legend(bbox_to_anchor = (1, 1))
